# %%
# import torch
import numpy as np
import pandas as pd
df1 = pd.read_excel("test_data.xlsx")
df2 =pd.read_excel("train_data.xlsx")
df1['BRD4-BD1'].dropna()
df2['BRD4-BD1'].dropna()
print(df2[['SMILES','BRD4-BD1']].shape)
# Out:
# (528, 2)

# %% [markdown]
# 数据预处理：选择是数字的行

# %%
df3=df2[['SMILES','BRD4-BD1','Class','Unit']][df2['BRD4-BD1'].apply(lambda x : type(x)==float)][df2['Class'].apply(lambda x:x=="IC50")].dropna()
df4=df1[['SMILES','BRD4-BD1','Class','Unit']][df1['BRD4-BD1'].apply(lambda x : type(x)==float)][df2['Class'].apply(lambda x:x=="IC50")].dropna()
df3.loc[df3['Unit']=='nM',['BRD4-BD1']] /=1000  # 训练样本
df3.loc[df3['Unit']=='nM',['Unit']] ='uM'
df4.loc[df4['Unit']=='nM',['BRD4-BD1']] /=1000 # 测试样本
df4.loc[df4['Unit']=='nM',['Unit']] ='uM'
df4=df4.reset_index()
df3 =df3.reset_index()
#print(X_train_smiles.shape,df3.shape)
#print(X_test_smiles.shape,df4)
# df3.to_csv(r'./train_check.csv',index=False,sep=',')  #重新保存
# df4.to_csv(r'./test_check.csv',index=False,sep=',') #重新保存

train_df = pd.read_csv("train_check.csv")
test_df =pd.read_csv("test_check.csv")
X_train_smiles = np.array(list(train_df["SMILES"]))
# # writer.save()
# print(X_train_smiles[1])
# Out:
# <ipython-input-41-e3241fd15991>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3=df2[['SMILES','BRD4-BD1','Class','Unit']][df2['BRD4-BD1'].apply(lambda x : type(x)==float)][df2['Class'].apply(lambda x:x=="IC50")].dropna()
# <ipython-input-41-e3241fd15991>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df4=df1[['SMILES','BRD4-BD1','Class','Unit']][df1['BRD4-BD1'].apply(lambda x : type(x)==float)][df2['Class'].apply(lambda x:x=="IC50")].dropna()

# %%
assay = "BRD4-BD1"  
Y_train = train_df[assay].values.reshape(-1,1)
Y_train = np.array(Y_train)
print(Y_train.shape)
print(Y_train)
# Out:
# (185, 1)
# [[3.371e+00]
#  [6.120e-01]
#  [1.603e+00]
#  [2.860e-01]
#  [6.150e-01]
#  [5.880e-01]
#  [6.870e-01]
#  [4.468e+00]
#  [5.133e+00]
#  [5.952e+00]
#  [1.220e-01]
#  [8.770e-02]
#  [1.300e-01]
#  [4.400e-01]
#  [1.100e+00]
#  [5.600e-03]
#  [2.950e-02]
#  [3.129e-01]
#  [5.100e+00]
#  [3.400e+00]
#  [4.900e-01]
#  [7.700e+00]
#  [9.800e+00]
#  [1.160e+01]
#  [1.820e+01]
#  [2.760e+01]
#  [4.280e+01]
#  [4.760e+01]
#  [2.500e-01]
#  [6.000e-01]
#  [2.000e-01]
#  [1.190e+00]
#  [9.390e+00]
#  [6.500e-01]
#  [1.520e+00]
#  [1.470e+00]
#  [1.010e+00]
#  [9.900e-01]
#  [7.190e+01]
#  [5.800e-01]
#  [5.000e-01]
#  [1.510e+00]
#  [1.430e+01]
#  [9.000e-02]
#  [9.000e-02]
#  [6.000e-01]
#  [1.300e-01]
#  [7.500e-01]
#  [1.425e+01]
#  [1.757e+01]
#  [9.510e+00]
#  [1.428e+01]
#  [1.910e+01]
#  [2.052e+01]
#  [2.850e+00]
#  [5.200e-01]
#  [9.900e-01]
#  [1.240e+00]
#  [2.600e+00]
#  [3.420e+00]
#  [1.500e-01]
#  [9.470e-01]
#  [1.873e+01]
#  [3.820e+01]
#  [4.011e+01]
#  [4.529e+01]
#  [4.921e+01]
#  [8.340e+00]
#  [6.670e+00]
#  [9.210e+00]
#  [2.510e+00]
#  [8.370e+00]
#  [9.710e+00]
#  [1.050e+01]
#  [3.360e+00]
#  [9.660e+00]
#  [4.700e+00]
#  [7.500e+00]
#  [2.870e-02]
#  [3.170e-02]
#  [2.550e-02]
#  [7.550e-02]
#  [8.060e-02]
#  [5.800e-02]
#  [1.000e-01]
#  [4.100e+00]
#  [1.400e+00]
#  [2.260e+00]
#  [2.060e+00]
#  [8.330e+00]
#  [7.340e+00]
#  [9.310e+00]
#  [5.820e+00]
#  [2.200e-01]
#  [7.600e-01]
#  [2.500e-01]
#  [5.000e-01]
#  [4.100e-01]
#  [8.000e-01]
#  [3.000e-01]
#  [6.000e-02]
#  [4.600e-01]
#  [1.400e-01]
#  [6.000e-02]
#  [2.200e-01]
#  [1.700e-01]
#  [9.300e-01]
#  [1.100e-01]
#  [7.900e-01]
#  [2.500e-01]
#  [5.100e+00]
#  [3.700e+00]
#  [2.900e+00]
#  [1.300e+00]
#  [1.700e+00]
#  [4.700e-01]
#  [1.800e+00]
#  [1.300e+00]
#  [3.820e-01]
#  [3.710e-01]
#  [5.000e-01]
#  [2.600e+00]
#  [5.500e-01]
#  [1.800e-03]
#  [1.100e-03]
#  [4.100e+00]
#  [2.300e-01]
#  [4.800e-01]
#  [1.070e+00]
#  [1.600e-01]
#  [2.000e-02]
#  [5.000e-02]
#  [1.290e-02]
#  [5.900e-02]
#  [1.300e+00]
#  [2.850e-02]
#  [3.430e-02]
#  [8.600e-03]
#  [5.700e-03]
#  [1.440e-02]
#  [5.200e-03]
#  [9.500e-03]
#  [9.400e-03]
#  [5.400e-03]
#  [5.800e-03]
#  [4.800e-03]
#  [5.900e-03]
#  [5.300e-03]
#  [4.600e-03]
#  [6.600e-03]
#  [8.700e-03]
#  [2.720e-02]
#  [7.900e-03]
#  [6.100e-03]
#  [2.050e-01]
#  [6.500e-01]
#  [1.860e-01]
#  [8.400e-02]
#  [2.579e+00]
#  [6.633e+00]
#  [1.880e+01]
#  [1.070e-01]
#  [4.890e-01]
#  [3.100e-01]
#  [4.210e-01]
#  [4.190e+01]
#  [1.201e+01]
#  [1.187e+01]
#  [3.870e+00]
#  [6.540e+00]
#  [3.340e+00]
#  [9.320e+00]
#  [4.630e+00]
#  [4.790e+00]
#  [2.730e+00]
#  [1.440e+00]
#  [1.990e+00]
#  [2.960e+00]
#  [2.543e+01]
#  [4.010e+01]
#  [3.590e+00]
#  [4.770e+00]
#  [4.730e+00]
#  [6.900e-01]
#  [6.300e-01]]

# %% [markdown]
# 对SMILES格式进行编码，构建语料库

# %%
"""为出现的字符构建字典"""
charset = set("".join(list(df3.SMILES))+"!E")
"""为字符构建索引"""
char_to_int = dict((c,i) for i,c in enumerate(charset))
int_to_char = dict((i,c) for i,c in enumerate(charset))
embed = max([len(smile) for smile in df3.SMILES]) + 5 # 最长的len(smile)
print (str(charset))
print(len(charset), embed)
char_to_int
# Out:
# {'l', 'g', '=', '5', 'C', '3', 'F', 'E', 'N', '#', '@', '1', '-', 'r', '[', '+', 'H', '*', 'B', '4', ')', 'M', 'S', ']', '2', 'O', '!', '('}
# 28 97
# {'l': 0,
#  'g': 1,
#  '=': 2,
#  '5': 3,
#  'C': 4,
#  '3': 5,
#  'F': 6,
#  'E': 7,
#  'N': 8,
#  '#': 9,
#  '@': 10,
#  '1': 11,
#  '-': 12,
#  'r': 13,
#  '[': 14,
#  '+': 15,
#  'H': 16,
#  '*': 17,
#  'B': 18,
#  '4': 19,
#  ')': 20,
#  'M': 21,
#  'S': 22,
#  ']': 23,
#  '2': 24,
#  'O': 25,
#  '!': 26,
#  '(': 27}

# %% [markdown]
# Onehot编码向量化

# %%
def vectorize(smiles):
        one_hot =  np.zeros((smiles.shape[0], embed , len(charset)),dtype=np.int8)
        # 为所有数据生成形状为（embed，len(charset))的onehot编码,
        for i,smile in enumerate(smiles):
            #encode the start char 开始编码为！
            one_hot[i,0,char_to_int["!"]] = 1
            #encode the rest of the chars
            for j,c in enumerate(smile):
                one_hot[i,j+1,char_to_int[c]] = 1
            #Encode endchar 结束编码为 E
            one_hot[i,len(smile)+1:,char_to_int["E"]] = 1
        #Return two, one for input and the other for output
        return one_hot[:,0:-1,:], one_hot[:,1:,:]

# %%
vocab_size=len(charset)
vocab_size
# Out:
# 28

# %%
import keras
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.layers import Dense, Dropout
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from sklearn.utils import shuffle
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Input, GlobalMaxPooling2D
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
print("Keras: %s"%keras.__version__)
# Out:
# Keras: 2.4.3

# %% [markdown]
# 定义网络

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100, input_length=embed-1)) # embeding 
model.add(keras.layers.Conv1D(192,10,activation='relu')) # Conv1D
model.add(BatchNormalization())
model.add(keras.layers.Conv1D(192,5,activation='relu'))
model.add(keras.layers.Conv1D(192,3,activation='relu'))
model.add(Flatten())
model.add(Dense(100, activation='relu')) # Dense 输出100维度
model.add(Dropout(0.4))
model.add(Dense(1, activation='linear'))

# %% [markdown]
# 相关判断系数

# %%
def coeff_determination(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
def get_lr_metric(optimizer):
    def lr(y_true, y_pred):
        return optimizer.lr
    return lr

# %%
from keras import optimizers
optimizer = Adam(lr=0.00025)
lr_metric = get_lr_metric(optimizer)
model.compile(loss="mse", optimizer=optimizer, metrics=[coeff_determination, lr_metric])

# %%
callbacks_list = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-15, verbose=1, mode='auto',cooldown=0),
    ModelCheckpoint(filepath="weights.best.hdf5", monitor='val_loss', save_best_only=True, verbose=1, mode='auto')
    
]

# %% [markdown]
# 训练函数,采用五折交叉验证

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=5,shuffle=True,random_state=7)
hist=[]
score =[]
def train(X_train_smiles,Y_train_smiles):
   for train_index, test_index in kf.split(X_train_smiles):
        X_train,X_test = X_train_smiles[train_index],X_train_smiles[test_index]
        Y_train,Y_test =Y_train_smiles [train_index],Y_train_smiles[test_index]
# X_train_smiles,Y_train,X_test_smiles,Y_test = next(get_data(X_train_smiles,Y_train))
        X_train, _ = vectorize(X_train)
        X_test, _ = vectorize(X_test)
       
        from keras import backend as K #转换为张量
        X_train = K.cast_to_floatx(X_train)
        Y_train = K.cast_to_floatx(Y_train)
        history =model.fit(x=np.argmax(X_train, axis=2), y=Y_train,
                              batch_size=32,
                              epochs=5,
                              validation_data=(np.argmax(X_test, axis=2),Y_test),
                              callbacks=callbacks_list)
        hist.append(history)
        scores = model.evaluate(np.argmax(X_test, axis=2), Y_test, verbose=0)
        score.append(scores)
        print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
        # mol_str_train=[]
        # mol_str_test=[]
       
        # """ 参数是训练和测试集的数量"""
        # for x in range(X_train.shape[0]):
        #     mol_str_train.append("".join([int_to_char[idx] for idx in np.argmax(X_train[x,:,:], axis=1)]))
        # for x in range(X_test.shape[0]):
        #     mol_str_test.append("".join([int_to_char[idx] for idx in np.argmax(X_test[x,:,:], axis=1)]))
train(X_train_smiles=X_train_smiles,Y_train_smiles=Y_train)
# Out:
# Epoch 1/5
# 4/5 [=======================>......] - ETA: 0s - loss: 4.5330 - coeff_determination: 0.9506 - lr: 1.0000e-15
# Epoch 00001: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 55ms/step - loss: 5.3100 - coeff_determination: 0.9345 - lr: 1.0000e-15 - val_loss: 24.8013 - val_coeff_determination: 0.7565 - val_lr: 1.0000e-15
# Epoch 2/5
# 4/5 [=======================>......] - ETA: 0s - loss: 5.3710 - coeff_determination: 0.8918 - lr: 1.0000e-15
# Epoch 00002: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 60ms/step - loss: 6.7653 - coeff_determination: 0.8886 - lr: 1.0000e-15 - val_loss: 24.8190 - val_coeff_determination: 0.7563 - val_lr: 1.0000e-15
# Epoch 3/5
# 5/5 [==============================] - ETA: 0s - loss: 10.6827 - coeff_determination: 0.8565 - lr: 1.0000e-15
# Epoch 00003: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 64ms/step - loss: 10.6827 - coeff_determination: 0.8565 - lr: 1.0000e-15 - val_loss: 24.8277 - val_coeff_determination: 0.7562 - val_lr: 1.0000e-15
# Epoch 4/5
# 5/5 [==============================] - ETA: 0s - loss: 7.1634 - coeff_determination: 0.8753 - lr: 1.0000e-15
# Epoch 00004: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 64ms/step - loss: 7.1634 - coeff_determination: 0.8753 - lr: 1.0000e-15 - val_loss: 24.8333 - val_coeff_determination: 0.7562 - val_lr: 1.0000e-15
# Epoch 5/5
# 4/5 [=======================>......] - ETA: 0s - loss: 3.5749 - coeff_determination: 0.9392 - lr: 1.0000e-15
# Epoch 00005: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 59ms/step - loss: 4.5793 - coeff_determination: 0.9277 - lr: 1.0000e-15 - val_loss: 24.8395 - val_coeff_determination: 0.7561 - val_lr: 1.0000e-15
# coeff_determination: 75.61%
# Epoch 1/5
# 4/5 [=======================>......] - ETA: 0s - loss: 20.1431 - coeff_determination: 0.7595 - lr: 1.0000e-15
# Epoch 00001: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 75ms/step - loss: 17.7640 - coeff_determination: 0.7454 - lr: 1.0000e-15 - val_loss: 7.1236 - val_coeff_determination: 0.4571 - val_lr: 1.0000e-15
# Epoch 2/5
# 5/5 [==============================] - ETA: 0s - loss: 9.6278 - coeff_determination: 0.8140 - lr: 1.0000e-15
# Epoch 00002: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 68ms/step - loss: 9.6278 - coeff_determination: 0.8140 - lr: 1.0000e-15 - val_loss: 7.1213 - val_coeff_determination: 0.4563 - val_lr: 1.0000e-15
# Epoch 3/5
# 4/5 [=======================>......] - ETA: 0s - loss: 8.6415 - coeff_determination: 0.8214 - lr: 1.0000e-15
# Epoch 00003: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 56ms/step - loss: 7.9692 - coeff_determination: 0.8541 - lr: 1.0000e-15 - val_loss: 7.1183 - val_coeff_determination: 0.4553 - val_lr: 1.0000e-15
# Epoch 4/5
# 4/5 [=======================>......] - ETA: 0s - loss: 12.0783 - coeff_determination: 0.8286 - lr: 1.0000e-15
# Epoch 00004: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 62ms/step - loss: 11.1582 - coeff_determination: 0.8307 - lr: 1.0000e-15 - val_loss: 7.1169 - val_coeff_determination: 0.4546 - val_lr: 1.0000e-15
# Epoch 5/5
# 5/5 [==============================] - ETA: 0s - loss: 8.4292 - coeff_determination: 0.8246 - lr: 1.0000e-15
# Epoch 00005: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 71ms/step - loss: 8.4292 - coeff_determination: 0.8246 - lr: 1.0000e-15 - val_loss: 7.1136 - val_coeff_determination: 0.4538 - val_lr: 1.0000e-15
# coeff_determination: 45.38%
# Epoch 1/5
# 5/5 [==============================] - ETA: 0s - loss: 13.9675 - coeff_determination: 0.8808 - lr: 1.0000e-15
# Epoch 00001: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 76ms/step - loss: 13.9675 - coeff_determination: 0.8808 - lr: 1.0000e-15 - val_loss: 1.3124 - val_coeff_determination: 0.8855 - val_lr: 1.0000e-15
# Epoch 2/5
# 4/5 [=======================>......] - ETA: 0s - loss: 12.4008 - coeff_determination: 0.7367 - lr: 1.0000e-15
# Epoch 00002: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 56ms/step - loss: 14.3140 - coeff_determination: 0.7756 - lr: 1.0000e-15 - val_loss: 1.3122 - val_coeff_determination: 0.8855 - val_lr: 1.0000e-15
# Epoch 3/5
# 4/5 [=======================>......] - ETA: 0s - loss: 24.2109 - coeff_determination: 0.8400 - lr: 1.0000e-15
# Epoch 00003: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 58ms/step - loss: 22.1212 - coeff_determination: 0.8499 - lr: 1.0000e-15 - val_loss: 1.3126 - val_coeff_determination: 0.8854 - val_lr: 1.0000e-15
# Epoch 4/5
# 4/5 [=======================>......] - ETA: 0s - loss: 12.5048 - coeff_determination: 0.8556 - lr: 1.0000e-15
# Epoch 00004: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 55ms/step - loss: 13.2226 - coeff_determination: 0.8657 - lr: 1.0000e-15 - val_loss: 1.3126 - val_coeff_determination: 0.8853 - val_lr: 1.0000e-15
# Epoch 5/5
# 4/5 [=======================>......] - ETA: 0s - loss: 16.9322 - coeff_determination: 0.8501 - lr: 1.0000e-15
# Epoch 00005: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 59ms/step - loss: 15.3117 - coeff_determination: 0.8770 - lr: 1.0000e-15 - val_loss: 1.3134 - val_coeff_determination: 0.8851 - val_lr: 1.0000e-15
# coeff_determination: 88.51%
# Epoch 1/5
# 4/5 [=======================>......] - ETA: 0s - loss: 10.7775 - coeff_determination: 0.9064 - lr: 1.0000e-15
# Epoch 00001: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 70ms/step - loss: 11.3120 - coeff_determination: 0.8639 - lr: 1.0000e-15 - val_loss: 2.8255 - val_coeff_determination: 0.9126 - val_lr: 1.0000e-15
# Epoch 2/5
# 4/5 [=======================>......] - ETA: 0s - loss: 18.2748 - coeff_determination: 0.8761 - lr: 1.0000e-15
# Epoch 00002: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 53ms/step - loss: 16.0701 - coeff_determination: 0.8689 - lr: 1.0000e-15 - val_loss: 2.8263 - val_coeff_determination: 0.9125 - val_lr: 1.0000e-15
# Epoch 3/5
# 4/5 [=======================>......] - ETA: 0s - loss: 9.4908 - coeff_determination: 0.9021 - lr: 1.0000e-15
# Epoch 00003: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 55ms/step - loss: 10.6795 - coeff_determination: 0.8967 - lr: 1.0000e-15 - val_loss: 2.8273 - val_coeff_determination: 0.9125 - val_lr: 1.0000e-15
# Epoch 4/5
# 4/5 [=======================>......] - ETA: 0s - loss: 19.3579 - coeff_determination: 0.8318 - lr: 1.0000e-15
# Epoch 00004: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 59ms/step - loss: 18.3619 - coeff_determination: 0.8552 - lr: 1.0000e-15 - val_loss: 2.8285 - val_coeff_determination: 0.9124 - val_lr: 1.0000e-15
# Epoch 5/5
# 4/5 [=======================>......] - ETA: 0s - loss: 9.4768 - coeff_determination: 0.8733 - lr: 1.0000e-15
# Epoch 00005: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 69ms/step - loss: 12.2222 - coeff_determination: 0.8694 - lr: 1.0000e-15 - val_loss: 2.8288 - val_coeff_determination: 0.9124 - val_lr: 1.0000e-15
# coeff_determination: 91.24%
# Epoch 1/5
# 4/5 [=======================>......] - ETA: 0s - loss: 7.8491 - coeff_determination: 0.8778 - lr: 1.0000e-15
# Epoch 00001: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 68ms/step - loss: 11.5036 - coeff_determination: 0.8520 - lr: 1.0000e-15 - val_loss: 5.1870 - val_coeff_determination: 0.9667 - val_lr: 1.0000e-15
# Epoch 2/5
# 4/5 [=======================>......] - ETA: 0s - loss: 13.7449 - coeff_determination: 0.8379 - lr: 1.0000e-15
# Epoch 00002: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 54ms/step - loss: 12.7232 - coeff_determination: 0.8619 - lr: 1.0000e-15 - val_loss: 5.1872 - val_coeff_determination: 0.9667 - val_lr: 1.0000e-15
# Epoch 3/5
# 5/5 [==============================] - ETA: 0s - loss: 10.0466 - coeff_determination: 0.8956 - lr: 1.0000e-15
# Epoch 00003: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 62ms/step - loss: 10.0466 - coeff_determination: 0.8956 - lr: 1.0000e-15 - val_loss: 5.1879 - val_coeff_determination: 0.9666 - val_lr: 1.0000e-15
# Epoch 4/5
# 4/5 [=======================>......] - ETA: 0s - loss: 11.8329 - coeff_determination: 0.8856 - lr: 1.0000e-15
# Epoch 00004: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 58ms/step - loss: 10.9353 - coeff_determination: 0.7952 - lr: 1.0000e-15 - val_loss: 5.1885 - val_coeff_determination: 0.9666 - val_lr: 1.0000e-15
# Epoch 5/5
# 4/5 [=======================>......] - ETA: 0s - loss: 10.5273 - coeff_determination: 0.8853 - lr: 1.0000e-15
# Epoch 00005: val_loss did not improve from 1.24800
# 5/5 [==============================] - 0s 62ms/step - loss: 9.7881 - coeff_determination: 0.9025 - lr: 1.0000e-15 - val_loss: 5.1877 - val_coeff_determination: 0.9666 - val_lr: 1.0000e-15
# coeff_determination: 96.66%

# %% [markdown]
# 观察结果

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# hist = hist[0].history
for history in hist:
    hist = history.history
    plt.figure(figsize=(10, 8))

    for label in ['val_coeff_determination','coeff_determination']:
        plt.subplot(221)
        plt.plot(hist[label], label = label)
        plt.legend()
        plt.xlabel("Epochs")
        plt.ylabel("coeff_determination")

    for label in ['val_loss','loss']:
        plt.subplot(222)
        plt.plot(hist[label], label = label)
        plt.legend()
        plt.xlabel("Epochs")
        plt.ylabel("loss")



    plt.subplot(223)
    plt.plot( hist['lr'],hist['val_coeff_determination']  )
    plt.legend()
    plt.xlabel("lr")
    plt.ylabel("val_coeff_determination")


    plt.subplot(224)
    plt.plot( hist['lr'],hist['val_loss']  )
    plt.legend()
    plt.xlabel("lr")
    plt.ylabel("val_loss")


    plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)
# Out:
# <ipython-input-53-aa1a69282044>:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(221)
# <ipython-input-53-aa1a69282044>:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(222)
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
X_test_smiles = np.array(list(test_df["SMILES"]))
X_test, _ = vectorize(X_test_smiles)
Y_test = test_df[assay].values.reshape(-1,1)
Y_test =np.array(Y_test)

# %%
for s in score:
    print(s)
# Out:
# [24.839548110961914, 0.7561242580413818, 1.0000000036274937e-15]
# [7.113553524017334, 0.4538036286830902, 1.0000000036274937e-15]
# [1.3133724927902222, 0.8850880265235901, 1.0000000036274937e-15]
# [2.8287580013275146, 0.912378191947937, 1.0000000036274937e-15]
# [5.187681674957275, 0.966614842414856, 1.0000000036274937e-15]

# %%
predict_test= model.predict(x=np.argmax(X_test, axis=2))
# print(Y_test[0:5],predict_test[0:5])
print((abs(predict_test-Y_test)/Y_test).mean())
# Out:
# 11.341986351374878
